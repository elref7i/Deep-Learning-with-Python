# %%
# %matplotlib inline
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport

# %%
database = pd.read_csv("D:\python\machinelearing\Popular_Baby_Names.csv")

# %%
database.describe(include='all')
# Out:
#         Year of Birth  Gender Ethnicity Child's First Name         Count  \
# count    57582.000000   57582     57582              57582  57582.000000
# unique            NaN       2         7               3211           NaN
# top               NaN  FEMALE  HISPANIC              Avery           NaN
# freq              NaN   29402     16930                114           NaN
# mean      2013.283352     NaN       NaN                NaN     33.929596
# std          2.056076     NaN       NaN                NaN     39.027451
# min       2011.000000     NaN       NaN                NaN     10.000000
# 25%       2012.000000     NaN       NaN                NaN     13.000000
# 50%       2013.000000     NaN       NaN                NaN     20.000000
# 75%       2014.000000     NaN       NaN                NaN     36.000000
# max       2019.000000     NaN       NaN                NaN    426.000000
#
#                 Rank
# count   57582.000000
# unique           NaN
# top              NaN
# ...

# %%
#BoxPLot
box = sb.boxplot(database["Rank"])

# %%
#linePlot
line = sb.lineplot(database['Count'])
# Out:
# D:\python\machinelearing\anacondadow\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\python\machinelearing\anacondadow\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#ScatterPlot
Scatter = sb.scatterplot(database["Rank"])

# %%
#Joinplot
Join = sb.jointplot(x='Count',y='Rank',data=database)
# Out:
# D:\python\machinelearing\anacondadow\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\python\machinelearing\anacondadow\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
ProfileReport(database)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v0.0.dev0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-03-12 22:19:20.339314&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
