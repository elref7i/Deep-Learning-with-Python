# %%
import pandas as pd

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv("D:\\python\\machinelearing\\tips.csv")
df.head()
# Out:
#    total_bill   tip       X smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66   ahmed     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['X'].unique()
# Out:
# array(['Female', 'ahmed', 'Male'], dtype=object)

# %%
label_encoder = LabelEncoder()

# %%
df.X = label_encoder.fit_transform(df.X)
df.head()
# Out:
#    total_bill   tip  X smoker  day    time  size
# 0       16.99  1.01  0     No  Sun  Dinner     2
# 1       10.34  1.66  2     No  Sun  Dinner     3
# 2       21.01  3.50  1     No  Sun  Dinner     3
# 3       23.68  3.31  1     No  Sun  Dinner     2
# 4       24.59  3.61  0     No  Sun  Dinner     4

# %%
df['time'] = label_encoder.fit_transform(df['time'])
df.head()
# Out:
#    total_bill   tip  X smoker  day  time  size
# 0       16.99  1.01  0     No  Sun     0     2
# 1       10.34  1.66  2     No  Sun     0     3
# 2       21.01  3.50  1     No  Sun     0     3
# 3       23.68  3.31  1     No  Sun     0     2
# 4       24.59  3.61  0     No  Sun     0     4
