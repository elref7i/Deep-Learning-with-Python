# %%
import pandas as pd

# %%
df =pd.read_csv('D:\python\machinelearing\mpg.csv',na_values=['?','UNDEFIND','N/a'])
df.head()
# Out:
#    Unnamed: 0 manufacturer model  displ    year  cyl       trans  drv   cty  \
# 0           1         audi    a4    NaN  1999.0  4.0    auto(l5)    f  18.0
# 1           2         audi    a4    NaN  1999.0  4.0  manual(m5)    f   NaN
# 2           3         audi   NaN    NaN     NaN  NaN         NaN  NaN   NaN
# 3           4         audi    a4    NaN     NaN  NaN         NaN    f   NaN
# 4           5         audi    a4    NaN     NaN  6.0    auto(l5)    f  16.0
#
#     hwy fl    class
# 0  29.0  p  compact
# 1  29.0  p  compact
# 2   NaN  p  compact
# 3   NaN  p  compact
# 4  26.0  p  compact

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# manufacturer     object
# model            object
# displ           float64
# year            float64
# cyl             float64
# trans            object
# drv              object
# cty             float64
# hwy             float64
# fl               object
# class            object
# dtype: object

# %%
df.isnull()
# Out:
#      Unnamed: 0  manufacturer  model  displ   year    cyl  trans    drv  \
# 0         False         False  False   True  False  False  False  False
# 1         False         False  False   True  False  False  False  False
# 2         False         False   True   True   True   True   True   True
# 3         False         False  False   True   True   True   True  False
# 4         False         False  False   True   True  False  False  False
# ..          ...           ...    ...    ...    ...    ...    ...    ...
# 229       False         False  False  False  False  False  False  False
# 230       False         False  False  False  False  False  False  False
# 231       False         False  False  False  False  False  False  False
# 232       False         False  False  False  False  False  False  False
# 233       False         False  False  False  False  False  False  False
#
#        cty    hwy     fl  class
# 0    False  False  False  False
# 1     True  False  False  False
# ...

# %%
sum_nan=df.isnull().sum()
sum_nan
# Out:
# Unnamed: 0       0
# manufacturer     0
# model            1
# displ           10
# year             7
# cyl              5
# trans            5
# drv              4
# cty              8
# hwy              6
# fl               0
# class            0
# dtype: int64

# %%
any_nan=df.isnull().any(axis=1)
any_nan
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 229    False
# 230    False
# 231    False
# 232    False
# 233     True
# Length: 234, dtype: bool

# %%
any_nan=df.isnull().any(axis=1)
df[any_nan]
# Out:
#      Unnamed: 0 manufacturer               model  displ    year  cyl  \
# 0             1         audi                  a4    NaN  1999.0  4.0
# 1             2         audi                  a4    NaN  1999.0  4.0
# 2             3         audi                 NaN    NaN     NaN  NaN
# 3             4         audi                  a4    NaN     NaN  NaN
# 4             5         audi                  a4    NaN     NaN  6.0
# 5             6         audi                  a4    2.0     NaN  6.0
# 8             9         audi          a4 quattro    NaN  1999.0  4.0
# 11           12         audi          a4 quattro    NaN  1999.0  6.0
# 12           13         audi          a4 quattro    NaN     NaN  NaN
# 13           14         audi          a4 quattro    NaN     NaN  NaN
# 14           15         audi          a4 quattro    NaN     NaN  NaN
# 19           20    chevrolet  c1500 suburban 2wd    2.0  2008.0  8.0
# 26           27    chevrolet            corvette    2.0  2008.0  8.0
# ...
